# %% [markdown]
# ### [Content Recommender Systems - TMDB](https://medium.com/@francescofranco_39234/4b314926c769)

# %%
import numpy as np
import pandas as pd

credits_data = 'https://github.com/andandandand/CSV-datasets/raw/refs/heads/master/tmdb_5000_credits.csv'
movies_data = 'https://github.com/andandandand/CSV-datasets/raw/refs/heads/master/tmdb_5000_movies.csv'

credits_df = pd.read_csv(credits_data)
movies_df = pd.read_csv(movies_data)

# %%
print("Credits")
display(credits_df.head())

print("\nMovies")
display(movies_df.head())
# Out:
# Credits
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
print("Credits")
display(credits_df.info())

print("\nMovies")
display(movies_df.info())
# Out:
# Credits
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB
# None
# Movies
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
# ...

# %%
print("Credits")
display(credits_df.describe())

print("\nMovies")
display(movies_df.describe())
# Out:
# Credits
#             movie_id
# count    4803.000000
# mean    57165.484281
# std     88694.614033
# min         5.000000
# 25%      9014.500000
# 50%     14629.000000
# 75%     58610.500000
# max    459488.000000
# Movies
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# ...

# %%
credits_df.columns = ['id','tittle','cast','crew']
movies_df = movies_df.merge(credits_df, on='id')

# %%
# Import TfidfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Define a TF-IDF Vectorizer object. Remove all the stopwords like 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

# Replace the NaN values with an empty string
movies_df['overview'] = movies_df['overview'].fillna('')

# Construct the TF-IDF matrix needed adapting and transforming the data
tfidf_matrix = tfidf.fit_transform(movies_df['overview'])

# Resturn the form of the TF-IDF matrix
display(tfidf_matrix.shape) # (4803, 20978)

# Calculate the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Construct and inverse map of indexes and titles  of films
indices = pd.Series(movies_df.index, index=movies_df['title']).drop_duplicates()

# Function that takes  the title of a film in input and returns the most similar film ps
def get_recommendations(title, cosine_sim=cosine_sim):
    # Obtain the index of the film that corresponds to the title
    idx = indices[title]

    # Obtain the similarity scores  beteen titles  of films and the chosen film s
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Order the films on the basis of similarity score
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Obtain the scores  of the 10 most similar films
    sim_scores = sim_scores[1:11]

    # Obtain the indices  of the films
    movie_indices = [i[0] for i in sim_scores]

    # Return the 10 most silimar films
    return movies_df['title'].iloc[movie_indices]
# Out:
# (4803, 20978)

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# 65                              The Dark Knight
# 299                              Batman Forever
# 428                              Batman Returns
# 1359                                     Batman
# 3854    Batman: The Dark Knight Returns, Part 2
# 119                               Batman Begins
# 2507                                  Slow Burn
# 9            Batman v Superman: Dawn of Justice
# 1181                                        JFK
# 210                              Batman & Robin
# Name: title, dtype: object

# %%
get_recommendations('The Avengers')
# Out:
# 7               Avengers: Age of Ultron
# 3144                            Plastic
# 1715                            Timecop
# 4124                 This Thing of Ours
# 3311              Thank You for Smoking
# 3033                      The Corruptor
# 588     Wall Street: Money Never Sleeps
# 2136         Team America: World Police
# 1468                       The Fountain
# 1286                        Snowpiercer
# Name: title, dtype: object

# %%
# Convert the characteristics from string format into corresponding Python object
from ast import literal_eval

features = ['cast', 'crew', 'keywords', 'genres']
for feature in features:
    movies_df[feature] = movies_df[feature].apply(literal_eval)


# Extract the director's name from the 'crew' characteristic. If not present, return NaN
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan


# Return the first 3 elements of the list or the entire list if it has less than 3 elementelementi
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        # Check if there are more than 3 elements. If yes, return only the first 3, else the entire list
        if len(names) > 3:
            names = names[:3]
        return names

    # Return an empty list in case of missing or invalid data
    return []


# Define new characteristics for the director, the cast, the genre, and the key ords in an adequate formin
movies_df['director'] = movies_df['crew'].apply(get_director)

features = ['cast', 'keywords', 'genres']
for feature in features:
    movies_df[feature] = movies_df[feature].apply(get_list)

# Print the new charcteristics for the first 3 films
movies_df[['title', 'cast', 'director', 'keywords', 'genres']].head(3)
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                cast        director  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]   James Cameron
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]  Gore Verbinski
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]      Sam Mendes
#
#                               keywords                        genres
# 0   [culture clash, future, space war]  [Action, Adventure, Fantasy]
# 1   [ocean, drug abuse, exotic island]  [Adventure, Fantasy, Action]
# 2  [spy, based on novel, secret agent]    [Action, Adventure, Crime]

# %%
# Function to convert all the lower-case strings and remove the spaces in names
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        # Check of the director exists. If not, return an empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# Apply the function clean_data to the chosen characteristics
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    movies_df[feature] = movies_df[feature].apply(clean_data)

# Function to create the "soup" of metadata combining key words, cast, director and genre generi
def create_soup(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])

movies_df['soup'] = movies_df.apply(create_soup, axis=1)

# Import CountVectorizer and create the counting matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(movies_df['soup'])

# Calculate the cosine similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# Reimpose the principal index DataFrane and construct the invere matrix like before
movies_df = movies_df.reset_index()
indices = pd.Series(movies_df.index, index=movies_df['title'])

# %%
get_recommendations('The Dark Knight Rises', cosine_sim2)
# Out:
# 65               The Dark Knight
# 119                Batman Begins
# 4638    Amidst the Devil's Wings
# 1196                The Prestige
# 3073           Romeo Is Bleeding
# 3326              Black November
# 1503                      Takers
# 1986                      Faster
# 303                     Catwoman
# 747               Gangster Squad
# Name: title, dtype: object

# %%
get_recommendations('The Godfather', cosine_sim2)
# Out:
# 867      The Godfather: Part III
# 2731      The Godfather: Part II
# 4638    Amidst the Devil's Wings
# 2649           The Son of No One
# 1525              Apocalypse Now
# 1018             The Cotton Club
# 1170     The Talented Mr. Ripley
# 1209               The Rainmaker
# 1394               Donnie Brasco
# 1850                    Scarface
# Name: title, dtype: object
