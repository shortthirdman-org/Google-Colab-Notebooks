# %% [markdown]
# ### [Decision Trees in Exploratory Data Analysis Toolkit](https://medium.com/data-science-collective/why-decision-trees-are-a-must-have-in-your-exploratory-data-analysis-toolkit-c6acd481cc76)

# %%
# !pip install --quiet ucimlrepo

# %%
# Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.tree import plot_tree

np.random.seed(42)
plt.style.use("ggplot")
sns.set_style()

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading a dataset
from ucimlrepo import fetch_ucirepo

# fetch dataset
student_performance = fetch_ucirepo(id=320)

# data (as pandas dataframes)
X = student_performance.data.features
y = student_performance.data.targets

# Gather X and Y for visualizations
df = pd.concat([X,y], axis=1)

display(df.sample(10))
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 220     GP   F   16       U     GT3       A     3     1  services     other
# 594     MS   F   18       U     GT3       T     4     4   teacher   teacher
# 429     MS   M   16       R     LE3       A     4     4   at_home     other
# 72      GP   F   15       R     GT3       T     1     1     other     other
# 448     MS   F   16       R     GT3       T     4     4   teacher   teacher
# 181     GP   F   16       U     GT3       T     4     2    health  services
# 131     GP   F   18       U     GT3       T     2     1  services     other
# 231     GP   M   18       U     LE3       T     3     3  services    health
# 277     GP   F   17       U     GT3       T     1     1     other  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 636  ...      3        2      4     1     4      2        4  17  18  19
# 220  ...      2        3      3     2     2      4        2  11  11  12
# 594  ...      4        3      5     1     2      1        0  18  18  18
# 429  ...      5        3      2     1     3      2        5  10  11  11
# 72   ...      3        3      4     2     4      5        2  13  11  11
# 448  ...      4        2      2     1     1      4        6  16  16  17
# 181  ...      4        2      3     1     1      3        0  17  17  18
# 131  ...      5        4      5     1     3      5       10  10   9   8
# 231  ...      3        2      4     2     4      4       10  10  10  10
# 277  ...      4        3      4     1     2      5        4  11  10  11
#
# [10 rows x 33 columns]

# %%
# Columns to explore
cols = ['failures', 'absences', 'studytime']

# Split X & Y
X = df[cols]
y = df.G3

# Fit Decision Tree
dt = DecisionTreeRegressor().fit(X,y)

# Plot DT
plt.figure(figsize=(20,10))
plot_tree(dt, filled=True, feature_names=X.columns, max_depth=3, fontsize=8);

# %%
# Columns to explore
cols = ['freetime', 'goout']

# Split X & Y
X = df[cols]
y = df.G3

# Fit Decision Tree
dt = DecisionTreeRegressor().fit(X,y)

# Plot DT
plt.figure(figsize=(20,10))
plot_tree(dt, filled=True, feature_names=X.columns, max_depth=3, fontsize=10)
# Out:
# [Text(0.6363636363636364, 0.9, 'goout <= 4.5\nsquared_error = 10.421\nsamples = 649\nvalue = 11.906'),
#  Text(0.36363636363636365, 0.7, 'goout <= 1.5\nsquared_error = 9.487\nsamples = 539\nvalue = 12.117'),
#  Text(0.5, 0.8, 'True  '),
#  Text(0.18181818181818182, 0.5, 'freetime <= 3.5\nsquared_error = 14.489\nsamples = 48\nvalue = 10.729'),
#  Text(0.09090909090909091, 0.3, 'freetime <= 1.5\nsquared_error = 17.139\nsamples = 38\nvalue = 10.421'),
#  Text(0.045454545454545456, 0.1, '\n  (...)  \n'),
#  Text(0.13636363636363635, 0.1, '\n  (...)  \n'),
#  Text(0.2727272727272727, 0.3, 'freetime <= 4.5\nsquared_error = 2.69\nsamples = 10\nvalue = 11.9'),
#  Text(0.22727272727272727, 0.1, '\n  (...)  \n'),
#  Text(0.3181818181818182, 0.1, '\n  (...)  \n'),
#  Text(0.5454545454545454, 0.5, 'freetime <= 2.5\nsquared_error = 8.792\nsamples = 491\nvalue = 12.253'),
#  Text(0.45454545454545453, 0.3, 'freetime <= 1.5\nsquared_error = 8.648\nsamples = 116\nvalue = 12.845'),
#  Text(0.4090909090909091, 0.1, '\n  (...)  \n'),
#  Text(0.5, 0.1, '\n  (...)  \n'),
#  Text(0.6363636363636364, 0.3, 'goout <= 2.5\nsquared_error = 8.694\nsamples = 375\nvalue = 12.069'),
#  Text(0.5909090909090909, 0.1, '\n  (...)  \n'),
#  Text(0.6818181818181818, 0.1, '\n  (...)  \n'),
#  Text(0.9090909090909091, 0.7, 'freetime <= 4.5\nsquared_error = 13.711\nsamples = 110\nvalue = 10.873'),
#  Text(0.7727272727272727, 0.8, '  False'),
#  Text(0.8636363636363636, 0.5, 'freetime <= 3.5\nsquared_error = 11.045\nsamples = 75\nvalue = 11.427'),
#  Text(0.8181818181818182, 0.3, 'freetime <= 2.5\nsquared_error = 10.778\nsamples = 39\nvalue = 11.872'),
#  Text(0.7727272727272727, 0.1, '\n  (...)  \n'),
#  Text(0.8636363636363636, 0.1, '\n  (...)  \n'),
#  Text(0.9090909090909091, 0.3, 'squared_error = 10.886\nsamples = 36\nvalue = 10.944'),
#  Text(0.9545454545454546, 0.5, 'squared_error = 17.358\nsamples = 35\nvalue = 9.686')]

# %%
# Load the dataset
df = sns.load_dataset('taxis').dropna()

# Columns to explore
cols = ['total']

# Split X & Y
X = df[cols]
y = df['payment']

# Fit Decision Tree
dt = DecisionTreeClassifier().fit(X,y)

# Plot Tree
plt.figure(figsize=(21,10))
plot_tree(dt, filled=True, feature_names=X.columns, max_depth=3,
          fontsize=10, class_names=['cash', 'credit_card']);
