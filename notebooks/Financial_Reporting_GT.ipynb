# %% [markdown]
# ### [Financial Reporting in Python With Great Tables](https://medium.com/data-science-collective/financial-reporting-in-python-with-great-tables-2db5b4227a98)
#
# **Great Tables** has features that handle specific requirements needed for financial reporting:
#
# - Precise number formatting (currency, percentages, basis points)
# - Professional styling that matches corporate standards
# - Clear hierarchies with column spanners and row groups
# - Summary calculations for totals and subtotals
# - Conditional formatting to highlight key metrics

# %%
# !pip install -q great_tables great_tables[extra]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.2/607.2 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.0/512.0 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 6.2 MB/s eta 0:00:00

# %% [markdown]
# #### **Basic Financial Statement**

# %%
import os, sys

import numpy as np
import pandas as pd

from IPython.display import display
from great_tables import GT, vals

import warnings
warnings.filterwarnings('ignore')

income_stmt = pd.DataFrame({
    'Line Item': [
        'Revenue',
        'Cost of Goods Sold',
        'Gross Profit',
        'Operating Expenses',
        'Operating Income',
        'Interest Expense',
        'Net Income'
    ],
    'Q3 2025': [2_450_000, -920_000, 1_530_000, -680_000, 850_000, -45_000, 805_000],
    'Q4 2025': [2_890_000, -1_050_000, 1_840_000, -720_000, 1_120_000, -42_000, 1_078_000],
    'YoY Change': [0.18, 0.14, 0.20, 0.06, 0.32, -0.07, 0.34]
})
display(income_stmt)
# Out:
#             Line Item  Q3 2025  Q4 2025  YoY Change
# 0             Revenue  2450000  2890000        0.18
# 1  Cost of Goods Sold  -920000 -1050000        0.14
# 2        Gross Profit  1530000  1840000        0.20
# 3  Operating Expenses  -680000  -720000        0.06
# 4    Operating Income   850000  1120000        0.32
# 5    Interest Expense   -45000   -42000       -0.07
# 6          Net Income   805000  1078000        0.34

# %%
financial_table = (
    GT(income_stmt)
    .tab_header(
        title="Income Statement",
        subtitle="Quarterly Results (USD)"
    )
    .fmt_currency(
        columns=['Q3 2025', 'Q4 2025'],
        currency='USD',
        decimals=0
    )
    .fmt_percent(
        columns='YoY Change',
        decimals=1
    )
    .opt_stylize(style=1, color='gray')
)

display(financial_table)
# Out:
# GT(_tbl_data=            Line Item  Q3 2025  Q4 2025  YoY Change
# 0             Revenue  2450000  2890000        0.18
# 1  Cost of Goods Sold  -920000 -1050000        0.14
# 2        Gross Profit  1530000  1840000        0.20
# 3  Operating Expenses  -680000  -720000        0.06
# 4    Operating Income   850000  1120000        0.32
# 5    Interest Expense   -45000   -42000       -0.07
# 6          Net Income   805000  1078000        0.34, _body=<great_tables._gt_data.Body object at 0x7f325efc0da0>, _boxhead=Boxhead([ColInfo(var='Line Item', type=<ColInfoTypeEnum.default: 1>, column_label='Line Item', column_align='left', column_width=None), ColInfo(var='Q3 2025', type=<ColInfoTypeEnum.default: 1>, column_label='Q3 2025', column_align='right', column_width=None), ColInfo(var='Q4 2025', type=<ColInfoTypeEnum.default: 1>, column_label='Q4 2025', column_align='right', column_width=None), ColInfo(var='YoY Change', type=<ColInfoTypeEnum.default: 1>, column_label='YoY Change', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f325f09db20>, _spanners=Spanners([]), _heading=Heading(title='Income Statement', subtitle='Quarterly Results (USD)', preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f324da88710>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f325f09d9d0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x7f324da88260>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f325fe853a0>, <great_tables._gt_data.FormatInfo object at 0x7f32749108c0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#000000'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#000000'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=Op ...

# %% [markdown]
# #### **Accounting Notation**

# %%
financial_table = (
    GT(income_stmt)
    .tab_header(title="Income Statement")
    .fmt_currency(
        columns=['Q3 2025', 'Q4 2025'],
        currency='USD',
        decimals=0,
        accounting=True
    )
    .fmt_percent(columns='YoY Change', decimals=1)
)
display(financial_table)
# Out:
# GT(_tbl_data=            Line Item  Q3 2025  Q4 2025  YoY Change
# 0             Revenue  2450000  2890000        0.18
# 1  Cost of Goods Sold  -920000 -1050000        0.14
# 2        Gross Profit  1530000  1840000        0.20
# 3  Operating Expenses  -680000  -720000        0.06
# 4    Operating Income   850000  1120000        0.32
# 5    Interest Expense   -45000   -42000       -0.07
# 6          Net Income   805000  1078000        0.34, _body=<great_tables._gt_data.Body object at 0x7f324da73ce0>, _boxhead=Boxhead([ColInfo(var='Line Item', type=<ColInfoTypeEnum.default: 1>, column_label='Line Item', column_align='left', column_width=None), ColInfo(var='Q3 2025', type=<ColInfoTypeEnum.default: 1>, column_label='Q3 2025', column_align='right', column_width=None), ColInfo(var='Q4 2025', type=<ColInfoTypeEnum.default: 1>, column_label='Q4 2025', column_align='right', column_width=None), ColInfo(var='YoY Change', type=<ColInfoTypeEnum.default: 1>, column_label='YoY Change', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f324da898e0>, _spanners=Spanners([]), _heading=Heading(title='Income Statement', subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f324da8bc20>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f324da8bf20>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x7f324da8ba70>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f324da73c80>, <great_tables._gt_data.FormatInfo object at 0x7f324da88d10>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True,  ...

# %% [markdown]
# #### **Summary Rows with Grand Totals**

# %%
financial_table = (
    GT(income_stmt, rowname_col="Line Item")
    .tab_header(title="Income Statement")
    .fmt_currency(columns=["Q3 2025", "Q4 2025"], currency="USD", decimals=0, accounting=True)
    .fmt_percent(columns="YoY Change", decimals=1)
    .grand_summary_rows(
        fns={"Total": lambda df: df[["Q3 2025", "Q4 2025"]].sum()}, fmt=vals.fmt_currency
    )
)

display(financial_table)
# Out:
# GT(_tbl_data=            Line Item  Q3 2025  Q4 2025  YoY Change
# 0             Revenue  2450000  2890000        0.18
# 1  Cost of Goods Sold  -920000 -1050000        0.14
# 2        Gross Profit  1530000  1840000        0.20
# 3  Operating Expenses  -680000  -720000        0.06
# 4    Operating Income   850000  1120000        0.32
# 5    Interest Expense   -45000   -42000       -0.07
# 6          Net Income   805000  1078000        0.34, _body=<great_tables._gt_data.Body object at 0x7f325efc0da0>, _boxhead=Boxhead([ColInfo(var='Line Item', type=<ColInfoTypeEnum.stub: 2>, column_label='Line Item', column_align='left', column_width=None), ColInfo(var='Q3 2025', type=<ColInfoTypeEnum.default: 1>, column_label='Q3 2025', column_align='right', column_width=None), ColInfo(var='Q4 2025', type=<ColInfoTypeEnum.default: 1>, column_label='Q4 2025', column_align='right', column_width=None), ColInfo(var='YoY Change', type=<ColInfoTypeEnum.default: 1>, column_label='YoY Change', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f324da88bc0>, _spanners=Spanners([]), _heading=Heading(title='Income Statement', subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f324da8af00>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f325fe850d0>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x7f324da8a270>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f325ef806e0>, <great_tables._gt_data.FormatInfo object at 0x7f325feb53a0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, cat ...

# %% [markdown]
# #### **Multiple Currencies**

# %%
multi_currency = pd.DataFrame(
    {
        "Region": ["North America", "Europe", "Asia Pacific"],
        "USD": [1_200_000, 890_000, 1_450_000],
        "EUR": [1_100_000, 820_000, 1_330_000],
        "JPY": [168_000_000, 124_000_000, 202_000_000],
    }
)

multi_currency_table = (
    GT(multi_currency)
    .tab_header(title="Regional Revenue by Currency")
    .fmt_currency(columns="USD", currency="USD", decimals=0)
    .fmt_currency(columns="EUR", currency="EUR", decimals=0)
    .fmt_currency(columns="JPY", currency="JPY", decimals=0)
)

display(multi_currency_table)
# Out:
# GT(_tbl_data=          Region      USD      EUR        JPY
# 0  North America  1200000  1100000  168000000
# 1         Europe   890000   820000  124000000
# 2   Asia Pacific  1450000  1330000  202000000, _body=<great_tables._gt_data.Body object at 0x7f324da8a900>, _boxhead=Boxhead([ColInfo(var='Region', type=<ColInfoTypeEnum.default: 1>, column_label='Region', column_align='left', column_width=None), ColInfo(var='USD', type=<ColInfoTypeEnum.default: 1>, column_label='USD', column_align='right', column_width=None), ColInfo(var='EUR', type=<ColInfoTypeEnum.default: 1>, column_label='EUR', column_align='right', column_width=None), ColInfo(var='JPY', type=<ColInfoTypeEnum.default: 1>, column_label='JPY', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f324da8af30>, _spanners=Spanners([]), _heading=Heading(title='Regional Revenue by Currency', subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f324da8b5f0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f324da8ad50>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x7f324da8a390>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f325efe3c80>, <great_tables._gt_data.FormatInfo object at 0x7f324e5f27b0>, <great_tables._gt_data.FormatInfo object at 0x7f324dc4a780>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_backgroun ...

# %% [markdown]
# #### **Column Spanners for Hierarchical Headers**

# %%
quarterly_comparison = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West'],
    'Q1_Revenue': [450_000, 380_000, 520_000, 410_000],
    'Q1_Profit': [67_500, 53_200, 78_000, 61_500],
    'Q2_Revenue': [485_000, 395_000, 548_000, 430_000],
    'Q2_Profit': [72_750, 55_300, 82_200, 64_500],
})

comparison_table = (
    GT(quarterly_comparison)
    .tab_header(title="Regional Financial Performance")
    .tab_spanner(label="Q1 2025", columns=['Q1_Revenue', 'Q1_Profit'])
    .tab_spanner(label="Q2 2025", columns=['Q2_Revenue', 'Q2_Profit'])
    .cols_label(
        Q1_Revenue='Revenue',
        Q1_Profit='Profit',
        Q2_Revenue='Revenue',
        Q2_Profit='Profit'
    )
    .fmt_currency(
        columns=['Q1_Revenue', 'Q1_Profit', 'Q2_Revenue', 'Q2_Profit'],
        currency='USD',
        decimals=0
    )
)

display(comparison_table)
# Out:
# GT(_tbl_data=  Region  Q1_Revenue  Q1_Profit  Q2_Revenue  Q2_Profit
# 0  North      450000      67500      485000      72750
# 1  South      380000      53200      395000      55300
# 2   East      520000      78000      548000      82200
# 3   West      410000      61500      430000      64500, _body=<great_tables._gt_data.Body object at 0x7f324daacd70>, _boxhead=Boxhead([ColInfo(var='Region', type=<ColInfoTypeEnum.default: 1>, column_label='Region', column_align='left', column_width=None), ColInfo(var='Q1_Revenue', type=<ColInfoTypeEnum.default: 1>, column_label='Revenue', column_align='right', column_width=None), ColInfo(var='Q1_Profit', type=<ColInfoTypeEnum.default: 1>, column_label='Profit', column_align='right', column_width=None), ColInfo(var='Q2_Revenue', type=<ColInfoTypeEnum.default: 1>, column_label='Revenue', column_align='right', column_width=None), ColInfo(var='Q2_Profit', type=<ColInfoTypeEnum.default: 1>, column_label='Profit', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f324daac500>, _spanners=Spanners([SpannerInfo(spanner_id='Q1 2025', spanner_level=0, spanner_label='Q1 2025', spanner_units=None, spanner_pattern=None, vars=['Q1_Revenue', 'Q1_Profit'], built=None), SpannerInfo(spanner_id='Q2 2025', spanner_level=0, spanner_label='Q2 2025', spanner_units=None, spanner_pattern=None, vars=['Q2_Revenue', 'Q2_Profit'], built=None)]), _heading=Heading(title='Regional Financial Performance', subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f324daad8e0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f324daad100>, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x7f324daacbf0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f324e174e30>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_colo ...

# %% [markdown]
# #### **Portfolio Performance Dashboard**

# %%
portfolio = pd.DataFrame({
    'Ticker': ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'TSLA'],
    'Company': ['Apple Inc.', 'Alphabet Inc.', 'Microsoft Corp.', 'Amazon.com Inc.', 'Tesla Inc.'],
    'Shares': [150, 50, 200, 75, 100],
    'Cost Basis': [142.50, 2_450.00, 285.00, 3_150.00, 195.00],
    'Current Price': [178.25, 2_890.00, 367.50, 3_520.00, 242.80],
    'Market Value': [26_737.50, 144_500.00, 73_500.00, 264_000.00, 24_280.00],
    'Gain/Loss': [5_362.50, 22_000.00, 16_500.00, 27_750.00, 4_780.00],
    'Return': [0.251, 0.179, 0.289, 0.117, 0.245]
})

portfolio_table = (
    GT(portfolio)
    .tab_header(
        title="Investment Portfolio Summary",
        subtitle="As of January 12, 2026"
    )
    .fmt_integer(columns='Shares')
    .fmt_currency(
        columns=['Cost Basis', 'Current Price', 'Market Value', 'Gain/Loss'],
        currency='USD',
        decimals=2
    )
    .fmt_percent(columns='Return', decimals=1)
    .data_color(
        columns='Return',
        palette=['#ef4444', '#ffffff', '#22c55e']
    )
    .tab_source_note(
        "Data is delayed by 15 minutes. Portfolio value: $533,017.50"
    )
    .opt_stylize(style=6, color='blue')
)

display(portfolio_table)
# Out:
# GT(_tbl_data=  Ticker          Company  Shares  Cost Basis  Current Price  Market Value  \
# 0   AAPL       Apple Inc.     150       142.5         178.25       26737.5
# 1  GOOGL    Alphabet Inc.      50      2450.0        2890.00      144500.0
# 2   MSFT  Microsoft Corp.     200       285.0         367.50       73500.0
# 3   AMZN  Amazon.com Inc.      75      3150.0        3520.00      264000.0
# 4   TSLA       Tesla Inc.     100       195.0         242.80       24280.0
#
#    Gain/Loss  Return
# 0     5362.5   0.251
# 1    22000.0   0.179
# 2    16500.0   0.289
# 3    27750.0   0.117
# 4     4780.0   0.245  , _body=<great_tables._gt_data.Body object at 0x7f324da89e20>, _boxhead=Boxhead([ColInfo(var='Ticker', type=<ColInfoTypeEnum.default: 1>, column_label='Ticker', column_align='left', column_width=None), ColInfo(var='Company', type=<ColInfoTypeEnum.default: 1>, column_label='Company', column_align='left', column_width=None), ColInfo(var='Shares', type=<ColInfoTypeEnum.default: 1>, column_label='Shares', column_align='right', column_width=None), ColInfo(var='Cost Basis', type=<ColInfoTypeEnum.default: 1>, column_label='Cost Basis', column_align='right', column_width=None), ColInfo(var='Current Price', type=<ColInfoTypeEnum.default: 1>, column_label='Current Price', column_align='right', column_width=None), ColInfo(var='Market Value', type=<ColInfoTypeEnum.default: 1>, column_label='Market Value', column_align='right', column_width=None), ColInfo(var='Gain/Loss', type=<ColInfoTypeEnum.default: 1>, column_label='Gain/Loss', column_align='right', column_width=None), ColInfo(var='Return', type=<ColInfoTypeEnum.default: 1>, column_label='Return', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f324da8a600>, _spanners=Spanners([]), _heading=Heading(title='Investment Portfolio Summary', subtitle='As of January 12, 2026', preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7f324da894c0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7f324da8ba40>, _source_notes=['Data is delayed by 15 minutes. Portfolio value: $533,017.50'], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Return', rows=[0], mask=None), grpname=None, colname='Return', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#84dfa5')]), StyleInfo(locname=LocBody(columns='Return', rows=[1], mask=None), grpname=None, colname='Return', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#fbcbcb')]), StyleInfo(locname=LocBody(columns='Return', rows=[2], mask=None), grpname=None, colname='Return', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#22c55e')]), StyleInfo(locname=LocBody(columns='Return', rows=[3], mask=None), grpname=None, colname='Return', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ef4444')]), StyleInfo(locname=LocBody(columns='Return', rows=[4], mask=None), grpname=None, colname='Return', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#93e3b0')])], _locale=<great_tables._gt_data.Locale object at 0x7f324da8bd40>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f324da88800>, <great_tables._gt_data.FormatInfo object at 0x7f3274910860>, <great_tables._gt_data.FormatInfo object at 0x7f3274912420>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='tab ...

# %% [markdown]
# #### **Export for Reports**

# %%
html_output = portfolio_table.as_raw_html()
latex_output = portfolio_table.as_latex()
if "google.colab" not in sys.modules:
  portfolio_table.save("./portfolio_table.png")

if (html_output is not None) and (latex_output is not None):
  print("HTML output:")
  display(html_output)

  print("Latex output:")
  display(latex_output)
# Out:
# HTML output:
# '<div id="vakfeqyxan" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">\n<style>\n#vakfeqyxan table {\n          font-family: -apple-system, BlinkMacSystemFont, \'Segoe UI\', Roboto, Oxygen, Ubuntu, Cantarell, \'Helvetica Neue\', \'Fira Sans\', \'Droid Sans\', Arial, sans-serif;\n          -webkit-font-smoothing: antialiased;\n          -moz-osx-font-smoothing: grayscale;\n        }\n\n#vakfeqyxan thead, tbody, tfoot, tr, td, th { border-style: none; }\n tr { background-color: transparent; }\n#vakfeqyxan p { margin: 0; padding: 0; }\n #vakfeqyxan .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 16px; font-weight: normal; font-style: normal; background-color: #FFFFFF; width: auto; border-top-style: solid; border-top-width: 2px; border-top-color: #5F5F5F; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #5F5F5F; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }\n #vakfeqyxan .gt_caption { padding-top: 4px; padding-bottom: 4px; }\n #vakfeqyxan .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: #FFFFFF; border-bottom-width: 0; }\n #vakfeqyxan .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: #FFFFFF; border-top-width: 0; }\n #vakfeqyxan .gt_heading { background-color: #FFFFFF; text-align: center; border-bottom-color: #FFFFFF; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }\n #vakfeqyxan .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #5F5F5F; }\n #vakfeqyxan .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #5F5F5F; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #5F5F5F; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }\n #vakfeqyxan .gt_col_heading { color: #FFFFFF; background-color: #0076BA; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }\n #vakfeqyxan .gt_column_spanner_outer { color: #FFFFFF; background-color: #0076BA; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }\n #vakfeqyxan .gt_column_spanner_outer:first-child { padding-left: 0; }\n #vakfeqyxan .gt_column_spanner_outer:last-child { padding-right: 0; }\n #vakfeqyxan .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #5F5F5F; vertical-align: bottom; padding-top: 5px; padding-bottom: 5px; overflow-x: hidden; display: inline-block; width: 100%; }\n #vakfeqyxan .gt_spanner_row { border-bottom-style: hidden; }\n #vakfeqyxan .gt_group_heading { padding-top: 8px; padding-bottom: 8px; padding-left: 5px; padding-right: 5px; color: #333333; background-color: #FFFFFF; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #5F5F5F; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #5F5F5F; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right- ...
# Latex output:
# '\\begin{table}[!t]\n\\caption*{\n{\\large Investment Portfolio Summary} \\\\\n{\\small As of January 12, 2026}\n} \n\n\\fontsize{12.0pt}{14.4pt}\\selectfont\n\n\\begin{tabular*}{\\linewidth}{@{\\extracolsep{\\fill}}llrrrrrr}\n\\toprule\nTicker & Company & Shares & Cost Basis & Current Price & Market Value & Gain/Loss & Return \\\\ \n\\midrule\\addlinespace[2.5pt]\nAAPL & Apple Inc. & 150 & \\$142.50 & \\$178.25 & \\$26,737.50 & \\$5,362.50 & 25.1\\% \\\\\nGOOGL & Alphabet Inc. & 50 & \\$2,450.00 & \\$2,890.00 & \\$144,500.00 & \\$22,000.00 & 17.9\\% \\\\\nMSFT & Microsoft Corp. & 200 & \\$285.00 & \\$367.50 & \\$73,500.00 & \\$16,500.00 & 28.9\\% \\\\\nAMZN & Amazon.com Inc. & 75 & \\$3,150.00 & \\$3,520.00 & \\$264,000.00 & \\$27,750.00 & 11.7\\% \\\\\nTSLA & Tesla Inc. & 100 & \\$195.00 & \\$242.80 & \\$24,280.00 & \\$4,780.00 & 24.5\\% \\\\\n\\bottomrule\n\\end{tabular*}\n\\begin{minipage}{\\linewidth}\nData is delayed by 15 minutes. Portfolio value: \\$533,017.50\\\\\n\\end{minipage}\n\\end{table}\n'
